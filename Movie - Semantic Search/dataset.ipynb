# %%
import pandas as pd

# %%
df = pd.read_csv('Movieset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  ID                                             Poster  \
# 0           0   0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1           1   1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2           2   2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3           3   3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4           4   4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                       Title  Year  Duration                 Genre  Rating  \
# 0  The Shawshank Redemption  1994       142                 Drama     9.3
# 1             The Godfather  1972       175          Crime, Drama     9.2
# 2           The Dark Knight  2008       152  Action, Crime, Drama     9.0
# 3    The Godfather: Part II  1974       202          Crime, Drama     9.0
# 4              12 Angry Men  1957        96          Crime, Drama     9.0
#
#                                             Overview              Director  \
# ...

# %%
df = df[["ID","Overview"]]

# %%
df.set_index("ID")
# Out:
#                                               Overview
# ID
# 0    Two imprisoned men bond over a number of years...
# 1    An organized crime dynasty's aging patriarch t...
# 2    When the menace known as the Joker wreaks havo...
# 3    The early life and career of Vito Corleone in ...
# 4    A jury holdout attempts to prevent a miscarria...
# ..                                                 ...
# 995  A young New York socialite becomes interested ...
# 996  Sprawling epic covering the life of a Texas ca...
# 997  In Hawaii in 1941, a private is cruelly punish...
# 998  Several survivors of a torpedoed merchant ship...
# 999  A man in London tries to help a counter-espion...
#
# [1000 rows x 1 columns]

# %%
df.to_csv("description.csv")

# %%
df1 = pd.read_csv("description.csv")

# %%
df1
# Out:
#      Unnamed: 0   ID                                           Overview
# 0             0    0  Two imprisoned men bond over a number of years...
# 1             1    1  An organized crime dynasty's aging patriarch t...
# 2             2    2  When the menace known as the Joker wreaks havo...
# 3             3    3  The early life and career of Vito Corleone in ...
# 4             4    4  A jury holdout attempts to prevent a miscarria...
# ..          ...  ...                                                ...
# 995         995  995  A young New York socialite becomes interested ...
# 996         996  996  Sprawling epic covering the life of a Texas ca...
# 997         997  997  In Hawaii in 1941, a private is cruelly punish...
# 998         998  998  Several survivors of a torpedoed merchant ship...
# 999         999  999  A man in London tries to help a counter-espion...
#
# [1000 rows x 3 columns]

# %%
df1 = df1.drop("Unnamed: 0",axis=1).set_index("ID")

# %%
df1.to_csv("desc.csv")

# %%
df2 = pd.read_csv("desc.csv")

# %%
df2
# Out:
#       ID                                           Overview
# 0      0  Two imprisoned men bond over a number of years...
# 1      1  An organized crime dynasty's aging patriarch t...
# 2      2  When the menace known as the Joker wreaks havo...
# 3      3  The early life and career of Vito Corleone in ...
# 4      4  A jury holdout attempts to prevent a miscarria...
# ..   ...                                                ...
# 995  995  A young New York socialite becomes interested ...
# 996  996  Sprawling epic covering the life of a Texas ca...
# 997  997  In Hawaii in 1941, a private is cruelly punish...
# 998  998  Several survivors of a torpedoed merchant ship...
# 999  999  A man in London tries to help a counter-espion...
#
# [1000 rows x 2 columns]
